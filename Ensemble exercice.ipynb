# %%
print('Hello world')
# Out:
# Hello world

# %%
result = 0
for i in range(10):
    result += i+1

print(result)
# Out:
# 55

# %%
result1 = 1
for u in range(1, 11):
    result1 = result1 * u

print(result1)
# Out:
# 3628800

# %%
# 27p44

rep = input('Nombre : ')

print('Méthode Lucian')
for i in range(len(rep)):
    print(rep[-(i+1)])
print()
print('Méthode Rphaëlle')
for i in reversed(rep):
    print(i)
# Out:
# Nombre : 1234567890
# Méthode Lucian
# 0
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
#
# Méthode Rphaëlle
# 0
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
# 13p42

pi = 3.14
def aire_cercle(rayon):
    return pi*rayon**2
print(aire_cercle(2))
# Out:
# 12.56

# %%
# 14p42

from math import *

d = 149597870
c = 299794.458
t = 40075
p = 814000000

temps_lumiere_soleil = d/c
vitesse_terre = (2*pi*d)/(365.25*24*60*60)
nb_signal_electrique = c/t
rayon_terre = t/(2*pi)
surface_terre = 4*pi*rayon_terre*rayon_terre
surface_terre_km2 = surface_terre/1000000
surface_emergee = surface_terre_km2*(1+0.707)
densite_moyenne_population = p/surface_emergee

print(temps_lumiere_soleil, 'secondes')
print(vitesse_terre, 'm/s, soit', vitesse_terre/1000*60*60, 'km/h')
print(nb_signal_electrique, 'tours')
print(surface_terre, 'm2, soit', surface_terre_km2/1000000, 'millions de ')
print(densite_moyenne_population, 'hab/km2')
# Out:
# 499.0014525218475 secondes
# 29.78525422622005 m/s, soit 107.22691521439219 km/h
# 7.480834884591391 tours
# 511207467.7042776 m2, soit 0.0005112074677042776 millions de
# 932811.0765380907 hab/km2

# %%
# 24p44
import random

for i in range(random.randint(1,10)):
    print('Ha'+'hi'*int(round(random.random(),1)*10))
# Out:
# Hahihihihihi
# Hahihihihihihihihi
# Hahihihi
# Hahi
# Hahihihihihihihihihi
# Hahihihihihihihihi
# Hahihihi
# Hahihihihihi
# Hahihihihihihihi

# %%
# 25p44

a,b = 15, 10
r = 0
while b != 0:
    r = a % b
    a = b
    b = r

print(a)
# Out:
# 5

# %%
# 27p44 Correction

a = 1029387264

while a!= 0:
    print(a%10)
    a //= 10
# Out:
# 4
# 6
# 2
# 7
# 8
# 3
# 9
# 2
# 0
# 1
